# %%
f = open('text.txt','w')

# %%
pwd
# Out:
# '/kaggle/working'

# %%
ls
# Out:
# text.txt

# %%
f.write('this is my first file to write')
# Out:
# 30

# %%
f.close()

# %%
f = open('text.txt','w')

# %%
f.write('this is my file')
# Out:
# 15

# %%
f.close()

# %%
f = open('text.txt','a')

# %%
f.write('this is my journey to learn data science')
# Out:
# 40

# %%
f.close()

# %%
f = open('text.txt','r')

# %%
f.read()
# Out:
# 'this is my journey to learn data science'

# %%
data = open('text.txt','r')

# %%
data.read()
# Out:
# 'this is my journey to learn data science'

# %%
data.readline()
# Out:
# ''

# %%
data.seek(0)
# Out:
# 0

# %%
data.readline()
# Out:
# 'this is my journey to learn data science'

# %%
data.seek(5)
# Out:
# 5

# %%
data.read()
# Out:
# 'is my journey to learn data science'

# %%
data1 = open('text.txt','r')

# %%
for i in data1:
    print(i)
# Out:
# this is my journey to learn data science

# %%
import os

# %%
os.path.getsize('text.txt')
# Out:
# 40

# %%
os.remove('text.txt')

# %%
f = open('test.txt','w')

# %%
f.write('i am a data science enthusiast')
# Out:
# 30

# %%
f.close()

# %%
os.rename('test.txt','new.txt')

# %%
import shutil

# %%
shutil.copy('new.txt','copy_new.txt')
# Out:
# 'copy_new.txt'

# %%
with open('new.txt','r') as f:
    print(f.read())
# Out:
# i am a data science enthusiast

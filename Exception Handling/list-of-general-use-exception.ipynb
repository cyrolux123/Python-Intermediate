# %%
try:
    a = 10 / 0
except ZeroDivisionError as e:
    print(e)
# Out:
# division by zero

# %%
try:
    int('nabin')
except (ValueError,TypeError) as e:
    print(e)
# Out:
# invalid literal for int() with base 10: 'nabin'

# %%
try:
    int('nabin')
except:
    print('This will catch an error')
# Out:
# This will catch an error

# %%
try:
    import nabin
except ImportError as e:
    print(e)
10/4
# Out:
# No module named 'nabin'
# 2.5

# %%
try:
    d = {'key':'nabin',1 : [2,3,4]}
    print(d['key2'])
except KeyError as e:
    print(e)
# Out:
# 'key2'

# %%
try:
    'nabin'.test()
except AttributeError as e:
    print(e)
# Out:
# 'str' object has no attribute 'test'

# %%
try:
    l  = [2,3,4,5]
    print(l[6])
except IndexError as e:
    print(e)
# Out:
# list index out of range

# %%
try:
    123 + 'nabin'
except TypeError as e:
    print(e)
# Out:
# unsupported operand type(s) for +: 'int' and 'str'

# %%
try:
    with open('test.txt','r') as f:
        f.read()
except FileNotFoundError as e:
    print(e)
# Out:
# [Errno 2] No such file or directory: 'test.txt'

# %%
try:
    with open('test.txt','r') as f:
        f.read()
except Exception as e: #genaric msut not be in top ,it msut be at bottom
    print(e)
except FileNotFoundError as e:
    print("test",e)
# Out:
# [Errno 2] No such file or directory: 'test.txt'

# %%
def test(file):
    try:
        with open('test.txt','r') as f:
            f.read()
    except Exception as e: #genaric msut not be in top ,it msut be at bottom
        print(e)
    except FileNotFoundError as e:
        print("test",e)

# %%
dir(Exception)
# Out:
# ['__cause__',
#  '__class__',
#  '__context__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__suppress_context__',
#  '__traceback__',
#  'args',
#  'with_traceback']

# %% [markdown]
# # OOPS stands for Object Oriented Programming System

# %%
a = 1

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
print(type('cyrolux'))
# Out:
# <class 'str'>

# %%
print(type([1,2,3,4]))
# Out:
# <class 'list'>

# %%
class test:
    pass

# %%
b = test()

# %%
type(b)
# Out:
# __main__.test

# %%
print(type(b))
# Out:
# <class '__main__.test'>

# %%
class cyrolux:
    def nk(self): #function defined inside the class must be binded with related class
        print('This is my pseudoname.')

# %%
nabin = cyrolux()

# %%
print(type(nabin))
# Out:
# <class '__main__.cyrolux'>

# %%
nabin.nk() #Error if self is not passed
# Out:
# This is my pseudoname.

# %%
bipin = cyrolux()

# %%
bipin.nk()
# Out:
# This is my pseudoname.

# %%
class texas: #init used to pass data specific to an object inside the class and work accoring to it
    def  __init__(self,phone_no,email_id,student_id):
        self.phone_no = phone_no
        self.email_id = email_id
        self.student_id = student_id
    def return_student_details(self):
        return self.student_id,self.phone_no,self.email_id

# %%
milan = texas() #Error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 milan = texas() #Error
#
# TypeError: texas.__init__() missing 3 required positional arguments: 'phone_no', 'email_id', and 'student_id'

# %%
milan = texas(9860,'milan@gmail.com',22)

# %%
milan.phone_no
# Out:
# 9860

# %%
milan.email_id
# Out:
# 'milan@gmail.com'

# %%
milan.return_student_details()
# Out:
# (22, 9860, 'milan@gmail.com')

# %%
avisek = texas(9898,'a@gmail.com',9)

# %%
avisek.return_student_details()
# Out:
# (9, 9898, 'a@gmail.com')

# %%
class texas1: #init used to pass data specific to an object inside the class and work accoring to it
    def  __init__(self,phone_no,email_id,student_id):
        self.phone_no1 = phone_no
        self.email_id1 = email_id
        self.student_id1 = student_id
    def return_student_details1(self):
        return self.student_id1,self.phone_no1,self.email_id1

# %%
arjun = texas1(9897,'arjun@gmail.com',1)

# %%
arjun

# %%
arjun.phone_no #Error
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 arjun.phone_no #Error
#
# AttributeError: 'texas1' object has no attribute 'phone_no'

# %%
arjun.phone_no1
# Out:
# 9897

# %%
arjun.return_student_details1()
# Out:
# (1, 9897, 'arjun@gmail.com')

# %%
class texas1: 
    def  __init__(nk,phone_no,email_id,student_id):
        nk.phone_no1 = phone_no
        nk.email_id1 = email_id
        nk.student_id1 = student_id
    def return_student_details1(self):
        return nk.student_id1,nk.phone_no1,nk.email_id1

# %%
sabin = texas1(9696,'sabin@gmail.com',33)

# %%
sabin.phone_no1
# Out:
# 9696

# %%
#first argument behaves as a pointer where self is not a reserved keyword
